# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
df  = pd.read_csv("C:\\Deep Learning\\NLP\\Sentiment_analysis.csv")

# %%
sia = SentimentIntensityAnalyzer()

# %%
df.head(3)
# Out:
#                         Text  Sentiment         Source             Date/Time  \
# 0       I love this product!   Positive        Twitter   2023-06-15 09:23:14
# 1  The service was terrible.   Negative   Yelp Reviews   2023-06-15 11:45:32
# 2     This movie is amazing!   Positive           IMDb   2023-06-15 14:10:22
#
#         User ID      Location   Confidence Score
# 0      @user123      New York               0.85
# 1       user456   Los Angeles               0.65
# 2   moviefan789        London               0.92

# %%
def scores(text):
    score =  sia.polarity_scores(text)['compound']
    if score >= 0.05:
        return "Posivite"
    elif score <= -0.05:
        return "Negative"
    else:
        return "Neutral"

# %%
df['Text_score'] = df['Text'].apply(scores)

# %%
df.head(10)
# Out:
#                                                 Text  Sentiment  \
# 0                               I love this product!   Positive
# 1                          The service was terrible.   Negative
# 2                             This movie is amazing!   Positive
# 3   I'm so disappointed with their customer support.   Negative
# 4                 Just had the best meal of my life!   Positive
# 5             The quality of this product is subpar.   Negative
# 6  I can't stop listening to this song. It's incr...   Positive
# 7        Their website is so user-friendly. Love it!   Positive
# 8               I loved the movie! It was fantastic!   Positive
# 9                 The customer service was terrible.   Negative
#
#                  Source             Date/Time            User ID  \
# 0               Twitter   2023-06-15 09:23:14           @user123
# 1          Yelp Reviews   2023-06-15 11:45:32            user456
# 2                  IMDb   2023-06-15 14:10:22        moviefan789
# 3          Online Forum   2023-06-15 17:35:11         forumuser1
# 4           TripAdvisor   2023-06-16 08:50:59           foodie22
# 5        Amazon Reviews   2023-06-16 10:15:27         shopper123
# 6               Spotify   2023-06-16 13:40:18      musiclover456
# 7   Website Testimonial   2023-06-16 16:05:36   testimonialuser1
# 8                  IMDb   2023-07-02 09:12:34            user123
# 9          Yelp Reviews   2023-07-02 10:45:21            user456
#
#          Location   Confidence Score Text_score
# 0        New York               0.85   Posivite
# 1     Los Angeles               0.65   Negative
# 2          London               0.92   Posivite
# 3         Toronto               0.78   Negative
# 4           Paris               0.88   Posivite
# 5   San Francisco               0.72    Neutral
# 6          Berlin               0.91   Posivite
# 7          Sydney               0.87   Posivite
# 8        New York               0.92   Posivite
# 9     Los Angeles               0.65   Negative
